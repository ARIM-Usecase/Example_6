# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import Resize 

import scipy.io as scio
from torch.utils.data import DataLoader, Dataset
import torchmetrics
from PIL import Image
from torchvision import transforms as tfs

import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from datetime import datetime
from sklearn.neighbors import LocalOutlierFactor as LOF
from sklearn import metrics

#DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
## Preprocess Spectra
yxqdata = scio.loadmat('./CAO.mat')
X_training_normal= yxqdata['X_training_normal']/6000
X_training = yxqdata['X_training']/6000
X_test = yxqdata['X_test']/6000
X_pre = yxqdata['X_pre']/6000

X_training_normal[X_training_normal<0]=0
X_training[X_training<0]=0
X_test[X_test<0]=0
X_pre[X_pre<0]=0

Y_training_normal = (yxqdata['Y_training_normal']).squeeze()
Y_training = (yxqdata['Y_training']).squeeze()
Y_test = (yxqdata['Y_test']).squeeze()
Y_pre = (yxqdata['Y_pre']).squeeze()

#resize
def data_resize(data,a,b):  
    data_1=np.moveaxis(data,-1, 0)  
    data_1 = torch.from_numpy(data_1.astype(np.float32)).unsqueeze(0) 
    torch_resize = Resize([a,b])  
    data_resize = torch_resize(data_1) 
    data_resize=data_resize.squeeze(0)  
    data_resize = data_resize.numpy() 
    data_resize=np.moveaxis(data_resize, 0, -1)  

    return data_resize

## 
X_training_normal=data_resize(X_training_normal,80,120)
X_training=data_resize(X_training,80,120)
X_test=data_resize(X_test,80,120)
X_pre=data_resize(X_pre,80,120)

# %%
#define Dataset
class yxqDataset(Dataset):
    def __init__(self, data, labels, transform=None, target_transform=None):
        self.labels = labels
        self.imgs = data
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        image = self.imgs[:,:,idx]
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

data_tf = transforms.ToTensor()  
trainset_normal = yxqDataset(X_training_normal, Y_training_normal, transform=data_tf)            
train_normal_loader = DataLoader(trainset_normal, batch_size=16,shuffle=True)

# %%
#define CAE
class ConvAutoencoder(nn.Module):
    def __init__(self):
            super(ConvAutoencoder, self).__init__()
            #encoder
            self.encoder1 = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1), 
            nn.ReLU())                                          
            self.max_pool1=nn.MaxPool2d(kernel_size=2,stride=2, return_indices=True)  
            self.encoder2 = nn.Sequential(                       
            nn.Conv2d(16, 32, kernel_size=3,stride=1, padding=0), 
            nn.ReLU())
            self.max_pool2=nn.MaxPool2d(kernel_size=2,stride=2, return_indices=True)  
           
            self.encoder_fc = nn.Sequential(
            nn.Flatten(start_dim=1),
            nn.Linear(in_features=32*19*29, out_features=120),
            nn.Linear(in_features=120, out_features=32))
         
            #dencoder
            self.dencoder_fc = nn.Sequential(   
            nn.Linear(in_features=32, out_features=120),
            nn.Linear(in_features=120, out_features=32*19*29),
            nn.Unflatten(dim=1,unflattened_size=(32, 19, 29)))
        
            self.maxunpool1=nn.MaxUnpool2d(kernel_size=2,stride=2)
            self.dencoder1 = nn.Sequential(
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=1, padding=0),
            nn.ReLU())
            self.maxunpool2=nn.MaxUnpool2d(kernel_size=2,stride=2)
            self.dencoder2 = nn.Sequential(
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=1, padding=1),
            nn.Tanh ())  
            
    def forward(self, x):
            x = self.encoder1(x)
            x,indices1 = self.max_pool1(x)
            x = self.encoder2(x)
            x,indices2 = self.max_pool2(x)
            encoder = self.encoder_fc(x)
            x = self.dencoder_fc(encoder)
            x = self.maxunpool1(x,indices2)
            x = self.dencoder1(x)
            x = self.maxunpool2(x,indices1)
            dencoder = self.dencoder2(x)
            return encoder,dencoder

# %%
model = ConvAutoencoder()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
df = pd.DataFrame(columns=['epoch','train_loss'])
df.to_csv('./result/CAO/loss/CAO_loss1.csv',index=False)

# %%
train_losses=[] 
list=[]
train_num = 0
train_loss_epoch=0
num_epochs = 350 
for epoch in range(num_epochs):
    train_loss = 0.0
    model.train() 
    for data in train_normal_loader:
        img, _ = data
        img=img.to(torch.float32)
        train_recon,train_recon2 = model(img)   
        train_recon2=train_recon2.to(torch.float32)
        loss = criterion(train_recon2, img)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss_epoch += loss.item() * img.size(0)
        train_num = train_num + img.size(0)
        train_loss = train_loss_epoch / train_num
    
    print(f'Epoch {epoch+1}/{num_epochs}, '
          f'Training Loss: {train_loss:.6f}, ')
    list = [epoch+1,train_loss]
    data = pd.DataFrame([list])
    data.to_csv('./result/CAO/loss/CAO_loss1.csv',mode='a',header=False,index=False)  
    train_losses.append(train_loss)

plt.plot(train_losses, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/350, Training Loss: 0.013524,
# Epoch 2/350, Training Loss: 0.009837,
# Epoch 3/350, Training Loss: 0.007988,
# Epoch 4/350, Training Loss: 0.006752,
# Epoch 5/350, Training Loss: 0.005873,
# Epoch 6/350, Training Loss: 0.005217,
# Epoch 7/350, Training Loss: 0.004719,
# Epoch 8/350, Training Loss: 0.004326,
# Epoch 9/350, Training Loss: 0.004008,
# Epoch 10/350, Training Loss: 0.003743,
# Epoch 11/350, Training Loss: 0.003519,
# Epoch 12/350, Training Loss: 0.003326,
# Epoch 13/350, Training Loss: 0.003158,
# Epoch 14/350, Training Loss: 0.003010,
# Epoch 15/350, Training Loss: 0.002877,
# Epoch 16/350, Training Loss: 0.002758,
# Epoch 17/350, Training Loss: 0.002647,
# Epoch 18/350, Training Loss: 0.002544,
# Epoch 19/350, Training Loss: 0.002445,
# Epoch 20/350, Training Loss: 0.002352,
# Epoch 21/350, Training Loss: 0.002266,
# Epoch 22/350, Training Loss: 0.002185,
# Epoch 23/350, Training Loss: 0.002110,
# Epoch 24/350, Training Loss: 0.002040,
# Epoch 25/350, Training Loss: 0.001975,
# Epoch 26/350, Training Loss: 0.001914,
# Epoch 27/350, Training Loss: 0.001858,
# Epoch 28/350, Training Loss: 0.001804,
# Epoch 29/350, Training Loss: 0.001753,
# Epoch 30/350, Training Loss: 0.001706,
# Epoch 31/350, Training Loss: 0.001660,
# Epoch 32/350, Training Loss: 0.001618,
# Epoch 33/350, Training Loss: 0.001577,
# Epoch 34/350, Training Loss: 0.001538,
# Epoch 35/350, Training Loss: 0.001501,
# Epoch 36/350, Training Loss: 0.001466,
# Epoch 37/350, Training Loss: 0.001432,
# Epoch 38/350, Training Loss: 0.001400,
# Epoch 39/350, Training Loss: 0.001370,
# Epoch 40/350, Training Loss: 0.001340,
# Epoch 41/350, Training Loss: 0.001312,
# Epoch 42/350, Training Loss: 0.001285,
# Epoch 43/350, Training Loss: 0.001258,
# Epoch 44/350, Training Loss: 0.001233,
# Epoch 45/350, Training Loss: 0.001209,
# Epoch 46/350, Training Loss: 0.001186,
# Epoch 47/350, Training Loss: 0.001163,
# Epoch 48/350, Training Loss: 0.001142,
# Epoch 49/350, Training Loss: 0.001121,
# Epoch 50/350, Training Loss: 0.001101,
# Epoch 51/350, Training Loss: 0.001081,
# Epoch 52/350, Training Loss: 0.001063,
# Epoch 53/350, Training Loss: 0.001044,
# Epoch 54/350, Training Loss: 0.001027,
# Epoch 55/350, Training Loss: 0.001010,
# Epoch 56/350, Training Loss: 0.000994,
# Epoch 57/350, Training Loss: 0.000978,
# Epoch 58/350, Training Loss: 0.000963,
# Epoch 59/350, Training Loss: 0.000948,
# Epoch 60/350, Training Loss: 0.000933,
# Epoch 61/350, Training Loss: 0.000919,
# Epoch 62/350, Training Loss: 0.000905,
# Epoch 63/350, Training Loss: 0.000892,
# Epoch 64/350, Training Loss: 0.000879,
# Epoch 65/350, Training Loss: 0.000866,
# Epoch 66/350, Training Loss: 0.000854,
# Epoch 67/350, Training Loss: 0.000842,
# Epoch 68/350, Training Loss: 0.000830,
# Epoch 69/350, Training Loss: 0.000819,
# Epoch 70/350, Training Loss: 0.000808,
# Epoch 71/350, Training Loss: 0.000797,
# Epoch 72/350, Training Loss: 0.000787,
# Epoch 73/350, Training Loss: 0.000776,
# Epoch 74/350, Training Loss: 0.000766,
# Epoch 75/350, Training Loss: 0.000757,
# Epoch 76/350, Training Loss: 0.000747,
# Epoch 77/350, Training Loss: 0.000738,
# Epoch 78/350, Training Loss: 0.000729,
# Epoch 79/350, Training Loss: 0.000720,
# Epoch 80/350, Training Loss: 0.000712,
# Epoch 81/350, Training Loss: 0.000703,
# Epoch 82/350, Training Loss: 0.000695,
# Epoch 83/350, Training Loss: 0.000687,
# Epoch 84/350, Training Loss: 0.000679,
# Epoch 85/350, Training Loss: 0.000672,
# Epoch 86/350, Training Loss: 0.000664,
# Epoch 87/350, Training Loss: 0.000657,
# Epoch 88/350, Training Loss: 0.000650,
# Epoch 89/350, Training Loss: 0.000643,
# Epoch 90/350, Training Loss: 0.000636,
# Epoch 91/350, Training Loss: 0.000629,
# Epoch 92/350, Training Loss: 0.000623,
# Epoch 93/350, Training Loss: 0.000616,
# Epoch 94/350, Training Loss: 0.000610,
# Epoch 95/350, Training Loss: 0.000604,
# Epoch 96/350, Training Loss: 0.000598,
# Epoch 97/350, Training Loss: 0.000592,
# Epoch 98/350, Training Loss: 0.000586,
# Epoch 99/350, Training Loss: 0.000580,
# Epoch 100/350, Training Loss: 0.000575,
# Epoch 101/350, Training Loss: 0.000569,
# Epoch 102/350, Training Loss: 0.000564,
# Epoch 103/350, Training Loss: 0.000559,
# Epoch 104/350, Training Loss: 0.000554,
# Epoch 105/350, Training Loss: 0.000548,
# Epoch 106/350, Training Loss: 0.000543,
# Epoch 107/350, Training Loss: 0.000539,
# Epoch 108/350, Training Loss: 0.000534,
# Epoch 109/350, Training Loss: 0.000529,
# Epoch 110/350, Training Loss: 0.000524,
# Epoch 111/350, Training Loss: 0.000520,
# Epoch 112/350, Training Loss: 0.000515,
# Epoch 113/350, Training Loss: 0.000511,
# Epoch 114/350, Training Loss: 0.000507,
# Epoch 115/350, Training Loss: 0.000502,
# Epoch 116/350, Training Loss: 0.000498,
# Epoch 117/350, Training Loss: 0.000494,
# Epoch 118/350, Training Loss: 0.000490,
# Epoch 119/350, Training Loss: 0.000486,
# Epoch 120/350, Training Loss: 0.000482,
# Epoch 121/350, Training Loss: 0.000478,
# Epoch 122/350, Training Loss: 0.000474,
# Epoch 123/350, Training Loss: 0.000471,
# Epoch 124/350, Training Loss: 0.000467,
# Epoch 125/350, Training Loss: 0.000463,
# Epoch 126/350, Training Loss: 0.000460,
# Epoch 127/350, Training Loss: 0.000456,
# Epoch 128/350, Training Loss: 0.000453,
# Epoch 129/350, Training Loss: 0.000449,
# Epoch 130/350, Training Loss: 0.000446,
# Epoch 131/350, Training Loss: 0.000443,
# Epoch 132/350, Training Loss: 0.000440,
# Epoch 133/350, Training Loss: 0.000436,
# Epoch 134/350, Training Loss: 0.000433,
# Epoch 135/350, Training Loss: 0.000430,
# Epoch 136/350, Training Loss: 0.000427,
# Epoch 137/350, Training Loss: 0.000424,
# Epoch 138/350, Training Loss: 0.000421,
# Epoch 139/350, Training Loss: 0.000418,
# Epoch 140/350, Training Loss: 0.000415,
# Epoch 141/350, Training Loss: 0.000412,
# Epoch 142/350, Training Loss: 0.000410,
# Epoch 143/350, Training Loss: 0.000407,
# Epoch 144/350, Training Loss: 0.000404,
# Epoch 145/350, Training Loss: 0.000401,
# Epoch 146/350, Training Loss: 0.000399,
# Epoch 147/350, Training Loss: 0.000396,
# Epoch 148/350, Training Loss: 0.000393,
# Epoch 149/350, Training Loss: 0.000391,
# Epoch 150/350, Training Loss: 0.000388,
# Epoch 151/350, Training Loss: 0.000386,
# Epoch 152/350, Training Loss: 0.000383,
# Epoch 153/350, Training Loss: 0.000381,
# Epoch 154/350, Training Loss: 0.000379,
# Epoch 155/350, Training Loss: 0.000376,
# Epoch 156/350, Training Loss: 0.000374,
# Epoch 157/350, Training Loss: 0.000372,
# Epoch 158/350, Training Loss: 0.000369,
# Epoch 159/350, Training Loss: 0.000367,
# Epoch 160/350, Training Loss: 0.000365,
# Epoch 161/350, Training Loss: 0.000363,
# Epoch 162/350, Training Loss: 0.000360,
# Epoch 163/350, Training Loss: 0.000358,
# Epoch 164/350, Training Loss: 0.000356,
# Epoch 165/350, Training Loss: 0.000354,
# Epoch 166/350, Training Loss: 0.000352,
# Epoch 167/350, Training Loss: 0.000350,
# Epoch 168/350, Training Loss: 0.000348,
# Epoch 169/350, Training Loss: 0.000346,
# Epoch 170/350, Training Loss: 0.000344,
# Epoch 171/350, Training Loss: 0.000342,
# Epoch 172/350, Training Loss: 0.000340,
# Epoch 173/350, Training Loss: 0.000338,
# Epoch 174/350, Training Loss: 0.000336,
# Epoch 175/350, Training Loss: 0.000334,
# Epoch 176/350, Training Loss: 0.000333,
# Epoch 177/350, Training Loss: 0.000331,
# Epoch 178/350, Training Loss: 0.000329,
# Epoch 179/350, Training Loss: 0.000327,
# Epoch 180/350, Training Loss: 0.000325,
# Epoch 181/350, Training Loss: 0.000324,
# Epoch 182/350, Training Loss: 0.000322,
# Epoch 183/350, Training Loss: 0.000320,
# Epoch 184/350, Training Loss: 0.000319,
# Epoch 185/350, Training Loss: 0.000317,
# Epoch 186/350, Training Loss: 0.000315,
# Epoch 187/350, Training Loss: 0.000314,
# Epoch 188/350, Training Loss: 0.000312,
# Epoch 189/350, Training Loss: 0.000310,
# Epoch 190/350, Training Loss: 0.000309,
# Epoch 191/350, Training Loss: 0.000307,
# Epoch 192/350, Training Loss: 0.000306,
# Epoch 193/350, Training Loss: 0.000304,
# Epoch 194/350, Training Loss: 0.000303,
# Epoch 195/350, Training Loss: 0.000301,
# Epoch 196/350, Training Loss: 0.000300,
# Epoch 197/350, Training Loss: 0.000298,
# Epoch 198/350, Training Loss: 0.000297,
# Epoch 199/350, Training Loss: 0.000295,
# Epoch 200/350, Training Loss: 0.000294,
# Epoch 201/350, Training Loss: 0.000292,
# Epoch 202/350, Training Loss: 0.000291,
# Epoch 203/350, Training Loss: 0.000290,
# Epoch 204/350, Training Loss: 0.000288,
# Epoch 205/350, Training Loss: 0.000287,
# Epoch 206/350, Training Loss: 0.000286,
# Epoch 207/350, Training Loss: 0.000284,
# Epoch 208/350, Training Loss: 0.000283,
# Epoch 209/350, Training Loss: 0.000282,
# Epoch 210/350, Training Loss: 0.000280,
# Epoch 211/350, Training Loss: 0.000279,
# Epoch 212/350, Training Loss: 0.000278,
# Epoch 213/350, Training Loss: 0.000276,
# Epoch 214/350, Training Loss: 0.000275,
# Epoch 215/350, Training Loss: 0.000274,
# Epoch 216/350, Training Loss: 0.000273,
# Epoch 217/350, Training Loss: 0.000271,
# Epoch 218/350, Training Loss: 0.000270,
# Epoch 219/350, Training Loss: 0.000269,
# Epoch 220/350, Training Loss: 0.000268,
# Epoch 221/350, Training Loss: 0.000267,
# Epoch 222/350, Training Loss: 0.000266,
# Epoch 223/350, Training Loss: 0.000264,
# Epoch 224/350, Training Loss: 0.000263,
# Epoch 225/350, Training Loss: 0.000262,
# Epoch 226/350, Training Loss: 0.000261,
# Epoch 227/350, Training Loss: 0.000260,
# Epoch 228/350, Training Loss: 0.000259,
# Epoch 229/350, Training Loss: 0.000258,
# Epoch 230/350, Training Loss: 0.000257,
# Epoch 231/350, Training Loss: 0.000255,
# Epoch 232/350, Training Loss: 0.000254,
# Epoch 233/350, Training Loss: 0.000253,
# Epoch 234/350, Training Loss: 0.000252,
# Epoch 235/350, Training Loss: 0.000251,
# Epoch 236/350, Training Loss: 0.000250,
# Epoch 237/350, Training Loss: 0.000249,
# Epoch 238/350, Training Loss: 0.000248,
# Epoch 239/350, Training Loss: 0.000247,
# Epoch 240/350, Training Loss: 0.000246,
# Epoch 241/350, Training Loss: 0.000245,
# Epoch 242/350, Training Loss: 0.000244,
# Epoch 243/350, Training Loss: 0.000243,
# Epoch 244/350, Training Loss: 0.000242,
# Epoch 245/350, Training Loss: 0.000241,
# Epoch 246/350, Training Loss: 0.000240,
# Epoch 247/350, Training Loss: 0.000239,
# Epoch 248/350, Training Loss: 0.000238,
# Epoch 249/350, Training Loss: 0.000237,
# Epoch 250/350, Training Loss: 0.000237,
# Epoch 251/350, Training Loss: 0.000236,
# Epoch 252/350, Training Loss: 0.000235,
# Epoch 253/350, Training Loss: 0.000234,
# Epoch 254/350, Training Loss: 0.000233,
# Epoch 255/350, Training Loss: 0.000232,
# Epoch 256/350, Training Loss: 0.000231,
# Epoch 257/350, Training Loss: 0.000230,
# Epoch 258/350, Training Loss: 0.000229,
# Epoch 259/350, Training Loss: 0.000229,
# Epoch 260/350, Training Loss: 0.000228,
# Epoch 261/350, Training Loss: 0.000227,
# Epoch 262/350, Training Loss: 0.000226,
# Epoch 263/350, Training Loss: 0.000225,
# Epoch 264/350, Training Loss: 0.000224,
# Epoch 265/350, Training Loss: 0.000223,
# Epoch 266/350, Training Loss: 0.000223,
# Epoch 267/350, Training Loss: 0.000222,
# Epoch 268/350, Training Loss: 0.000221,
# Epoch 269/350, Training Loss: 0.000220,
# Epoch 270/350, Training Loss: 0.000219,
# Epoch 271/350, Training Loss: 0.000219,
# Epoch 272/350, Training Loss: 0.000218,
# Epoch 273/350, Training Loss: 0.000217,
# Epoch 274/350, Training Loss: 0.000216,
# Epoch 275/350, Training Loss: 0.000216,
# Epoch 276/350, Training Loss: 0.000215,
# Epoch 277/350, Training Loss: 0.000214,
# Epoch 278/350, Training Loss: 0.000213,
# Epoch 279/350, Training Loss: 0.000213,
# Epoch 280/350, Training Loss: 0.000212,
# Epoch 281/350, Training Loss: 0.000211,
# Epoch 282/350, Training Loss: 0.000210,
# Epoch 283/350, Training Loss: 0.000210,
# Epoch 284/350, Training Loss: 0.000209,
# Epoch 285/350, Training Loss: 0.000208,
# Epoch 286/350, Training Loss: 0.000207,
# Epoch 287/350, Training Loss: 0.000207,
# Epoch 288/350, Training Loss: 0.000206,
# Epoch 289/350, Training Loss: 0.000205,
# Epoch 290/350, Training Loss: 0.000205,
# Epoch 291/350, Training Loss: 0.000204,
# Epoch 292/350, Training Loss: 0.000203,
# Epoch 293/350, Training Loss: 0.000203,
# Epoch 294/350, Training Loss: 0.000202,
# Epoch 295/350, Training Loss: 0.000201,
# Epoch 296/350, Training Loss: 0.000201,
# Epoch 297/350, Training Loss: 0.000200,
# Epoch 298/350, Training Loss: 0.000199,
# Epoch 299/350, Training Loss: 0.000199,
# Epoch 300/350, Training Loss: 0.000198,
# Epoch 301/350, Training Loss: 0.000197,
# Epoch 302/350, Training Loss: 0.000197,
# Epoch 303/350, Training Loss: 0.000196,
# Epoch 304/350, Training Loss: 0.000195,
# Epoch 305/350, Training Loss: 0.000195,
# Epoch 306/350, Training Loss: 0.000194,
# Epoch 307/350, Training Loss: 0.000194,
# Epoch 308/350, Training Loss: 0.000193,
# Epoch 309/350, Training Loss: 0.000192,
# Epoch 310/350, Training Loss: 0.000192,
# Epoch 311/350, Training Loss: 0.000191,
# Epoch 312/350, Training Loss: 0.000191,
# Epoch 313/350, Training Loss: 0.000190,
# Epoch 314/350, Training Loss: 0.000189,
# Epoch 315/350, Training Loss: 0.000189,
# Epoch 316/350, Training Loss: 0.000188,
# Epoch 317/350, Training Loss: 0.000188,
# Epoch 318/350, Training Loss: 0.000187,
# Epoch 319/350, Training Loss: 0.000187,
# Epoch 320/350, Training Loss: 0.000186,
# Epoch 321/350, Training Loss: 0.000185,
# Epoch 322/350, Training Loss: 0.000185,
# Epoch 323/350, Training Loss: 0.000184,
# Epoch 324/350, Training Loss: 0.000184,
# Epoch 325/350, Training Loss: 0.000183,
# Epoch 326/350, Training Loss: 0.000183,
# Epoch 327/350, Training Loss: 0.000182,
# Epoch 328/350, Training Loss: 0.000182,
# Epoch 329/350, Training Loss: 0.000181,
# Epoch 330/350, Training Loss: 0.000181,
# Epoch 331/350, Training Loss: 0.000180,
# Epoch 332/350, Training Loss: 0.000179,
# Epoch 333/350, Training Loss: 0.000179,
# Epoch 334/350, Training Loss: 0.000178,
# Epoch 335/350, Training Loss: 0.000178,
# Epoch 336/350, Training Loss: 0.000177,
# Epoch 337/350, Training Loss: 0.000177,
# Epoch 338/350, Training Loss: 0.000176,
# Epoch 339/350, Training Loss: 0.000176,
# Epoch 340/350, Training Loss: 0.000175,
# Epoch 341/350, Training Loss: 0.000175,
# Epoch 342/350, Training Loss: 0.000174,
# Epoch 343/350, Training Loss: 0.000174,
# Epoch 344/350, Training Loss: 0.000173,
# Epoch 345/350, Training Loss: 0.000173,
# Epoch 346/350, Training Loss: 0.000172,
# Epoch 347/350, Training Loss: 0.000172,
# Epoch 348/350, Training Loss: 0.000171,
# Epoch 349/350, Training Loss: 0.000171,
# Epoch 350/350, Training Loss: 0.000170,

# %%
n=5
fig = plt.figure()
for i in range(n):
    plt.subplot(2,n,i+1) 
    imgs = trainset_normal[i][0].unsqueeze(0) 
    plt.imshow(imgs.squeeze().numpy())  
    with torch.no_grad():
        imgs=imgs.to(torch.float32)
        output_1, output_2 = model(imgs)  
        plt.subplot(2, n, i + 1 + n)        
        output_2=output_2.view(1,80,120) 
        plt.imshow(output_2.squeeze().numpy())

# %%
#torch.save(model.state_dict(), './model_CAO_1'))

# %%
#load model
model.load_state_dict(torch.load('./model_CAO.pt'))

# Dataloader
training_normal_loader = DataLoader(trainset_normal,shuffle=False) 
trainset = yxqDataset(X_training, Y_training, transform=data_tf)                
training_loader = DataLoader(trainset,shuffle=False) 
testset = yxqDataset(X_test, Y_test, transform=data_tf)              
test_loader = DataLoader(testset,shuffle=False) 
preset = yxqDataset(X_pre, Y_pre, transform=data_tf)                
pre_loader = DataLoader(preset,shuffle=False)
# Out:
# C:\Users\japan\AppData\Local\Temp\ipykernel_13984\2624624924.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./model_CAO.pt'))

# %%
def CAE(loader):
    recon_list=[]
    recon2_list=[]
    loss_list=[]
    labels_list=[]
    model.eval()  
    for i, data in enumerate(loader):
        img, labels = data
        img=img.to(torch.float32)
        recon,recon2 = model(img)
        loss = criterion(recon2, img)
        loss_list.append(loss.item())
        recon_list.extend(recon.to('cpu').detach().numpy()) 
        recon2_list.extend(recon2.to('cpu').detach().numpy())
        labels_list.extend(labels.to('cpu').numpy())
    
    labels=np.array(labels_list) 
    loss=np.array(loss_list)
    recon=np.array(recon_list)
    recon2_list = torch.tensor(recon2_list) 
    k=np.size(recon2_list,0) 
    recon2_list=recon2_list.view(1*k,80,120)
    recon2_list =recon2_list.detach().numpy()
    
    return labels,loss,recon,recon2_list

# %%
#reconstruction loss and hide layer data on training normal set
training_normal_label,training_normal_loss,training_normal_recon,training_normal_recon2=CAE(training_normal_loader)
# Out:
# C:\Users\japan\AppData\Local\Temp\ipykernel_13984\2237082213.py:20: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   recon2_list = torch.tensor(recon2_list)

# %%
def box_outlier(df,label):  
    Q1 = df.quantile(q=0.25)  
    Q3 = df.quantile(q=0.75)  
    
    up_whisker=Q3+1.5*(Q3-Q1) 
    low_whisker=Q1-1.5*(Q3 - Q1) 
    
    kk = df[(df > up_whisker) | (df < low_whisker)]
    data = pd.DataFrame({'id': kk.index, 'Outlier': kk,'label':label[kk.index]})

    return data,Q1,Q3,up_whisker,low_whisker,kk,kk.index

df = pd.DataFrame(training_normal_loss, columns= ['value'])
df= df.iloc[:,0]  
result,Q1,Q3,up_whisker,low_whisker,kk,kk.index = box_outlier(df,training_normal_label)

import matplotlib.pyplot as plt
fig,axes = plt.subplots()
df.plot(kind='box',ax=axes)
# Out:
# <Axes: >

# %%
#LOF model
from pyod.models.lof import LOF
clf_name = 'LOF'
clf = LOF(contamination = 0.01) 
clf.fit(training_normal_recon)
training_normal_pred = clf.predict(training_normal_recon)  

print("confusion_matrix:\n", metrics.confusion_matrix(training_normal_label,training_normal_pred))
# Out:
# confusion_matrix:
#  [[125]]
# C:\Users\japan\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
# obtained the reconstruction loss and hide layer data on training, test and prediction sets
training_label,training_loss,training_recon,training_recon2=CAE(training_loader)
test_label,test_loss,test_recon,test_recon2=CAE(test_loader)
pre_label,pre_loss,pre_recon,pre_recon2=CAE(pre_loader)

# %%
#define the OCC_CAE classify based on box and lof 
#define the OCC_CAE classify based on box and lof 
def OCC_CAE_class(label,loss,recon,up_whisker,training_normal_recon):
    loss_index_abnormal_1=np.flatnonzero(loss>up_whisker)
    k=len(label) 
    Boxplot_prelabel = np.zeros(k)
    Boxplot_prelabel[loss_index_abnormal_1] = 1
    
    clf = LOF(contamination = 0.01) 
    clf.fit(training_normal_recon)
    LOF_prelabel = clf.predict(recon) 
    
    OC_CAE_prelabel=Boxplot_prelabel+LOF_prelabel
    OC_CAE_prelabel_abnormal_index=np.flatnonzero(OC_CAE_prelabel > 0 )
    OC_CAE_prelabel_normal_index=np.flatnonzero(OC_CAE_prelabel == 0 )
    
    OC_CAE_prelabel[OC_CAE_prelabel_abnormal_index]=1
    OC_CAE_prelabel[OC_CAE_prelabel_normal_index]=0
    
    return label,Boxplot_prelabel,LOF_prelabel,OC_CAE_prelabel

# %%
label_training,Boxplot_training,LOF_training,OC_CAE_training=OCC_CAE_class(training_label,training_loss,training_recon,up_whisker,training_normal_recon)
print("Training Set Classification:")
print("Boxplot confusion_matrix:\n", metrics.confusion_matrix(label_training,Boxplot_training))
print("LOF confusion_matrix:\n", metrics.confusion_matrix(label_training,LOF_training))
print("OC_CAE confusion_matrix:\n", metrics.confusion_matrix(label_training,OC_CAE_training))
tp, fn, fp, tn = metrics.confusion_matrix(label_training,OC_CAE_training).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(label_training,OC_CAE_training))
print('Specificity（特异性）：',Specificity)
# Out:
# Training Set Classification:
# Boxplot confusion_matrix:
#  [[25  0]
#  [ 0 72]]
# LOF confusion_matrix:
#  [[25  0]
#  [29 43]]
# OC_CAE confusion_matrix:
#  [[25  0]
#  [ 0 72]]
# tp: 25, fn: 0, fp: 0, tn: 72
# Accuracy: 1.0
# Specificity（特异性）： 1.0

# %%
label_test,Boxplot_test,LOF_test,OC_CAE_test=OCC_CAE_class(test_label,test_loss,test_recon,up_whisker,training_normal_recon)
print("Prediction Set Classification:")
print("Boxplot confusion_matrix:\n", metrics.confusion_matrix(label_test,Boxplot_test))
print("LOF confusion_matrix:\n", metrics.confusion_matrix(label_test,LOF_test))
print("OC_CAE confusion_matrix:\n", metrics.confusion_matrix(label_test,OC_CAE_test))
tp, fn, fp, tn = metrics.confusion_matrix(label_test,OC_CAE_test).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(label_test,OC_CAE_test))
print('Specificity（特异性）：',Specificity)
# Out:
# Prediction Set Classification:
# Boxplot confusion_matrix:
#  [[ 6  2]
#  [ 0 24]]
# LOF confusion_matrix:
#  [[ 7  1]
#  [ 9 15]]
# OC_CAE confusion_matrix:
#  [[ 6  2]
#  [ 0 24]]
# tp: 6, fn: 2, fp: 0, tn: 24
# Accuracy: 0.9375
# Specificity（特异性）： 1.0

# %%
label_pre,Boxplot_pre,LOF_pre,OC_CAE_pre=OCC_CAE_class(pre_label,pre_loss,pre_recon,up_whisker,training_normal_recon)
print("Prediction Set Classification:")
print("Boxplot confusion_matrix:\n", metrics.confusion_matrix(label_pre,Boxplot_pre))
print("LOF confusion_matrix:\n", metrics.confusion_matrix(label_pre,LOF_pre))
print("OC_CAE confusion_matrix:\n", metrics.confusion_matrix(label_pre,OC_CAE_pre))
tp, fn, fp, tn = metrics.confusion_matrix(label_pre,OC_CAE_pre).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(label_pre,OC_CAE_pre))
print('Specificity（特异性）：',Specificity)
# Out:
# Prediction Set Classification:
# Boxplot confusion_matrix:
#  [[3 0]
#  [0 9]]
# LOF confusion_matrix:
#  [[3 0]
#  [4 5]]
# OC_CAE confusion_matrix:
#  [[3 0]
#  [0 9]]
# tp: 3, fn: 0, fp: 0, tn: 9
# Accuracy: 1.0
# Specificity（特异性）： 1.0

# %%
# reshape data
k_training_normal=np.size(X_training_normal,2)
X_training_normal_reshape=X_training_normal.transpose(2, 0, 1) 
X_training_normal_reshape=X_training_normal_reshape.reshape(k_training_normal,9600)  

k_training=np.size(X_training,2)
X_training_reshape=X_training.transpose(2, 0, 1) 
X_training_reshape=X_training_reshape.reshape(k_training,9600) 

k_test=np.size(X_test,2)
X_test_reshape=X_test.transpose(2, 0, 1) 
X_test_reshape=X_test_reshape.reshape(k_test,9600)  
print(X_test_reshape.shape)

k_pre=np.size(X_pre,2)
X_pre_reshape=X_pre.transpose(2, 0, 1) 
X_pre_reshape=X_pre_reshape.reshape(k_pre,9600)
# Out:
# (32, 9600)

# %%
#Boxplot
def dist(X):
    sample=np.size(X,0)
    dist_list=[]
    for i in range(sample):
        data=X[i,:]
        sum=0
        for j in range(9600):
            sum+=data[j]**2
            dist = np.sqrt(sum)
        dist_list.append(dist.item())
    dist_list =torch.tensor(dist_list)
    return dist_list

##
dist_training_normal=dist(X_training_normal_reshape)
dist_training=dist(X_training_reshape)
dist_test=dist(X_test_reshape)
dist_pre=dist(X_pre_reshape)

##
df = pd.DataFrame(dist_training_normal, columns= ['value'])
df= df.iloc[:,0]  
result,Q1,Q3,up_whisker,low_whisker,kk,kk.index = box_outlier(df,Y_training_normal)

##
def dist_boxclass(dist,label,up_whisker,low_whisker):
    dist_index_abnormal_1=np.flatnonzero(dist<low_whisker) 
    dist_index_abnormal_2=np.flatnonzero(dist>up_whisker)  
    k=len(label)
    dist_prelabel = np.zeros(k)
    dist_prelabel[dist_index_abnormal_1] = 1
    dist_prelabel[dist_index_abnormal_2] = 1
    return dist_prelabel

##
dist_trainlabel=dist_boxclass(dist_training,Y_training,up_whisker,low_whisker)
print('Classification results of Training Set:')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_training,dist_trainlabel))
tp, fn, fp, tn = metrics.confusion_matrix(Y_training,dist_trainlabel).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_training,dist_trainlabel))
print('Specificity（特异性）：',Specificity)
print('')

dist_testlabel=dist_boxclass(dist_test,Y_test,up_whisker,low_whisker)
print('Classification results of Test Set:')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_test,dist_testlabel))
tp, fn, fp, tn = metrics.confusion_matrix(Y_test,dist_testlabel).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_test,dist_testlabel))
print('Specificity（特异性）：',Specificity)
print('')

dist_prelabel=dist_boxclass(dist_pre,Y_pre,up_whisker,low_whisker)
print('Classification results of Prediction Set:')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_pre,dist_prelabel))
tp, fn, fp, tn = metrics.confusion_matrix(Y_pre,dist_prelabel).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_pre,dist_prelabel))
print('Specificity（特异性）：',Specificity)
# Out:
# Classification results of Training Set:
# confusion_matrix:
#  [[20  5]
#  [69  3]]
# tp: 20, fn: 5, fp: 69, tn: 3
# Accuracy: 0.23711340206185566
# Specificity（特异性）： 0.041666666666666664
#
# Classification results of Test Set:
# confusion_matrix:
#  [[ 8  0]
#  [23  1]]
# tp: 8, fn: 0, fp: 23, tn: 1
# Accuracy: 0.28125
# Specificity（特异性）： 0.041666666666666664
#
# Classification results of Prediction Set:
# confusion_matrix:
#  [[3 0]
#  [7 2]]
# tp: 3, fn: 0, fp: 7, tn: 2
# Accuracy: 0.4166666666666667
# Specificity（特异性）： 0.2222222222222222

# %%
#LOF algorithm
from pyod.models.lof import LOF
clf_name = 'LOF'
clf = LOF(contamination = 0.01) 
clf.fit(X_training_normal_reshape)

lof_trainlabel = clf.predict(X_training_reshape)
print('Classification results of Training Set:')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_training,lof_trainlabel))
tp, fn, fp, tn = metrics.confusion_matrix(Y_training,lof_trainlabel).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_training,lof_trainlabel))
print('Specificity（特异性）：',Specificity)
print('')

lof_testlabel = clf.predict(X_test_reshape)
print('Classification results of Test Set:')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_test,lof_testlabel))
tp, fn, fp, tn = metrics.confusion_matrix(Y_test,lof_testlabel).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_test,lof_testlabel))
print('Specificity（特异性）：',Specificity)
print('')

lof_prelabel = clf.predict(X_pre_reshape)
print('Classification results of Prediction Set:')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_pre,lof_prelabel))
tp, fn, fp, tn = metrics.confusion_matrix(Y_pre,lof_prelabel).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_pre,lof_prelabel))
print('Specificity（特异性）：',Specificity)
# Out:
# Classification results of Training Set:
# confusion_matrix:
#  [[25  0]
#  [23 49]]
# tp: 25, fn: 0, fp: 23, tn: 49
# Accuracy: 0.7628865979381443
# Specificity（特异性）： 0.6805555555555556
#
# Classification results of Test Set:
# confusion_matrix:
#  [[ 7  1]
#  [ 8 16]]
# tp: 7, fn: 1, fp: 8, tn: 16
# Accuracy: 0.71875
# Specificity（特异性）： 0.6666666666666666
#
# Classification results of Prediction Set:
# confusion_matrix:
#  [[3 0]
#  [3 6]]
# tp: 3, fn: 0, fp: 3, tn: 6
# Accuracy: 0.75
# Specificity（特异性）： 0.6666666666666666

# %%
#OC_SVM
gammas = np.logspace(-4, 2, 7)
nus = np.linspace(0.01, 0.99, 99)
from sklearn.svm import OneClassSVM
##  grid search start
best_score=0
clf = OneClassSVM()
results = []
results_2=[]
for gamma in gammas:
    for nu in nus:
        clf.set_params(kernel='rbf',gamma=gamma, nu=nu)
        clf.fit(X_training_normal_reshape)
      
        y_training = clf.predict(X_training_reshape)
        y_training_normal=np.flatnonzero(y_training == 1)
        y_training_abnormal=np.flatnonzero(y_training == -1)
        y_training[y_training_normal]=0
        y_training[y_training_abnormal]=1
        y_training_score=metrics.accuracy_score(Y_training, y_training)
      
        y_test = clf.predict(X_test_reshape)
        y_test_normal=np.flatnonzero(y_test  == 1)
        y_test_abnormal=np.flatnonzero(y_test  == -1)
        y_test[y_test_normal]=0
        y_test[y_test_abnormal]=1
        y_test_score=metrics.accuracy_score(Y_test, y_test)
      
        y_pre = clf.predict(X_pre_reshape)
        y_pre_normal=np.flatnonzero(y_pre == 1)
        y_pre_abnormal=np.flatnonzero(y_pre == -1)
        y_pre[y_pre_normal]=0
        y_pre[y_pre_abnormal]=1
        y_pre_score=metrics.accuracy_score(Y_pre, y_pre)
        score=y_training_score+y_test_score+y_pre_score
        if score > best_score:#find the optimized parameter;
            best_score = score
            best_parameters = {'gamma':gamma,'nu':nu}
            score_results={'Training_score':y_training_score,'Test_score':y_pre_score}
#  grid search end
print("Best score:{:.2f}".format(best_score))
print("Score:{}".format(score_results))
print("Best parameters:{}".format(best_parameters))

###
model_1 = OneClassSVM(kernel='rbf', nu=0.06, gamma=1)
model_1.fit(X_training_normal_reshape)

##
def OneSVM_class(X_reshape):
    OneSVM_normal = model_1.predict(X_reshape)   
    OneSVM_normal_index=np.flatnonzero(OneSVM_normal == 1)
    OneSVM_abnormal_index=np.flatnonzero(OneSVM_normal == -1)
    OneSVM_normal[OneSVM_normal_index]=0
    OneSVM_normal[OneSVM_abnormal_index]=1
    return OneSVM_normal

##
OneSVM_training_label=OneSVM_class(X_training_reshape)
print('Classification results of Training Set')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_training,OneSVM_training_label))
tp, fn, fp, tn = metrics.confusion_matrix(Y_training,OneSVM_training_label).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_training,OneSVM_training_label))
print('Specificity（特异性）：',Specificity)
print('')

OneSVM_test_label=OneSVM_class(X_test_reshape)
print('Classification results of Test Set')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_test,OneSVM_test_label))
tp, fn, fp, tn = metrics.confusion_matrix(Y_test,OneSVM_test_label).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_test,OneSVM_test_label))
print('Specificity（特异性）：',Specificity)


OneSVM_pre_label=OneSVM_class(X_pre_reshape)
print('Classification results of Prediction Set')
print("confusion_matrix:\n", metrics.confusion_matrix(Y_pre,OneSVM_pre_label))
tp, fn, fp, tn = metrics.confusion_matrix(Y_pre,OneSVM_pre_label).ravel()
print("tp: {}, fn: {}, fp: {}, tn: {}".format(tp, fn, fp, tn)) 
Specificity = tn / (tn + fp)  
print('Accuracy:',metrics.accuracy_score(Y_pre,OneSVM_pre_label))
print('Specificity（特异性）：',Specificity)
# Out:
# Best score:2.78
# Score:{'Training_score': 0.9381443298969072, 'Test_score': 1.0}
# Best parameters:{'gamma': 1.0, 'nu': 0.060000000000000005}
# Classification results of Training Set
# confusion_matrix:
#  [[22  3]
#  [ 3 69]]
# tp: 22, fn: 3, fp: 3, tn: 69
# Accuracy: 0.9381443298969072
# Specificity（特异性）： 0.9583333333333334
#
# Classification results of Test Set
# confusion_matrix:
#  [[ 4  4]
#  [ 1 23]]
# tp: 4, fn: 4, fp: 1, tn: 23
# Accuracy: 0.84375
# Specificity（特异性）： 0.9583333333333334
# Classification results of Prediction Set
# confusion_matrix:
#  [[3 0]
#  [0 9]]
# tp: 3, fn: 0, fp: 0, tn: 9
# Accuracy: 1.0
# Specificity（特异性）： 1.0
